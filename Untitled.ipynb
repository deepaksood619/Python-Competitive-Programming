# %%
data = b'[{"uuid": "db7b0dff-1762-55b0-80bb-17c372663691", "Custom": {"last_value": "2.5", "last_time": "1539976567000"}, "Path": "/Dominos-58/TemperatureSensor102/Temperature", "Readings": [[1540208566000.0, 2.31]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "Celsius", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "Temperature", "HARDWARE_VERSION": "13", "ADDRESS": "2C:3A:E8:18:49:20", "Operator": "null[]", "FIRMWARE_VERSION": "4.3.1", "WIFI_SSID": "ZT_MAIN_DOM58"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Makeline", "Model": "TemperatureLite", "MeterID": "102", "DeviceType": "temperature", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "b432ad91-e1a3-5575-ba3f-c1662353e60e", "Custom": {"last_value": "6.2618355751", "last_time": "1539976551000"}, "Path": "/Dominos-58/Meter5/CurrentRPhase", "Readings": [[1540208575000.0, 0.0]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "CurrentRPhase", "B_PHASE_MULTIPLIER": "None", "B_PHASE": "Oven", "VARIABLE_B_PHASE": "3", "R_PHASE_MULTIPLIER": "None", "VARIABLE_Y_PHASE": "2", "R_PHASE": "Oven", "Y_PHASE": "Oven", "MODBUS_ID": "5", "Operator": "null[]", "Y_PHASE_MULTIPLIER": "None", "VARIABLE_R_PHASE": "1"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Spare", "Model": "LGPlus", "MeterID": "5", "DeviceType": "meter", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "499b7503-ad0a-5387-b86e-94b5647b09a5", "Custom": {"last_value": "1.43213379383", "last_time": "1539976552000"}, "Path": "/Dominos-58/Meter6/CurrentRPhase", "Readings": [[1540208576000.0, 11.295389175415039]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "CurrentRPhase", "B_PHASE_MULTIPLIER": "None", "B_PHASE": "Not Defined", "VARIABLE_B_PHASE": "None", "R_PHASE_MULTIPLIER": "None", "VARIABLE_Y_PHASE": "None", "R_PHASE": "Cold Room", "Y_PHASE": "AC Outdoor Unit", "MODBUS_ID": "6", "Operator": "null[]", "Y_PHASE_MULTIPLIER": "None", "VARIABLE_R_PHASE": "None"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Spare", "Model": "LGPlus", "MeterID": "6", "DeviceType": "meter", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "9dd44bcd-3787-5b7f-9706-ca470f1e4a0b", "Custom": {"last_value": "0.0", "last_time": "1539976551000"}, "Path": "/Dominos-58/Meter5/CurrentBPhase", "Readings": [[1540208575000.0, 0.0]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "CurrentBPhase", "B_PHASE_MULTIPLIER": "None", "B_PHASE": "Oven", "VARIABLE_B_PHASE": "3", "R_PHASE_MULTIPLIER": "None", "VARIABLE_Y_PHASE": "2", "R_PHASE": "Oven", "Y_PHASE": "Oven", "MODBUS_ID": "5", "Operator": "null[]", "Y_PHASE_MULTIPLIER": "None", "VARIABLE_R_PHASE": "1"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Spare", "Model": "LGPlus", "MeterID": "5", "DeviceType": "meter", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "0bc04e60-8897-5f1c-9b64-43e45804cbbe", "Custom": {"last_value": "1.58747076988", "last_time": "1539976550000"}, "Path": "/Dominos-58/Meter4/CurrentYPhase", "Readings": [[1540208575000.0, 1.565172791481018]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "CurrentYPhase", "B_PHASE_MULTIPLIER": "None", "B_PHASE": "Lighting + Signage", "VARIABLE_B_PHASE": "None", "R_PHASE_MULTIPLIER": "None", "VARIABLE_Y_PHASE": "None", "R_PHASE": "Makeline", "Y_PHASE": "Exhaust Y Phase", "MODBUS_ID": "4", "Operator": "null[]", "Y_PHASE_MULTIPLIER": "None", "VARIABLE_R_PHASE": "None"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Spare", "Model": "LGPlus", "MeterID": "4", "DeviceType": "meter", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "2e3f2c32-be8c-5dc2-856f-f136544fa892", "Custom": {"last_value": "7.5", "last_time": "1539976570000"}, "Path": "/Dominos-58/TemperatureSensor100/Temperature", "Readings": [[1540208568000.0, 5.75]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "Celsius", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "Temperature", "HARDWARE_VERSION": "13", "ADDRESS": "2C:3A:E8:17:F6:DD", "Operator": "null[]", "FIRMWARE_VERSION": "4.3.1", "WIFI_SSID": "ZT_MAIN_DOM58"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Cold Room", "Model": "TemperatureLite", "MeterID": "100", "DeviceType": "temperature", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "d237583f-1a22-5717-a8d6-b530275d584f", "Custom": {"last_value": "32.43", "last_time": "1539976572000"}, "Path": "/Dominos-58/TemperatureSensor103/Temperature", "Readings": [[1540208575000.0, 29.75]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "Celsius", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "Temperature", "HARDWARE_VERSION": "13", "ADDRESS": "2C:3A:E8:17:F4:20", "Operator": "null[]", "FIRMWARE_VERSION": "4.3.1", "WIFI_SSID": "ZT_MAIN_DOM58"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Production Area", "Model": "TemperatureLite", "MeterID": "103", "DeviceType": "temperature", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "dc329766-9a84-5814-a639-05c6acab82fa", "Custom": {"last_value": "0.0", "last_time": "1539976551000"}, "Path": "/Dominos-58/Meter5/CurrentYPhase", "Readings": [[1540208575000.0, 6.4251933097839355]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "CurrentYPhase", "B_PHASE_MULTIPLIER": "None", "B_PHASE": "Oven", "VARIABLE_B_PHASE": "3", "R_PHASE_MULTIPLIER": "None", "VARIABLE_Y_PHASE": "2", "R_PHASE": "Oven", "Y_PHASE": "Oven", "MODBUS_ID": "5", "Operator": "null[]", "Y_PHASE_MULTIPLIER": "None", "VARIABLE_R_PHASE": "1"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Spare", "Model": "LGPlus", "MeterID": "5", "DeviceType": "meter", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "27fd04f8-82a1-57b8-bf1a-da5b91174d97", "Custom": {"last_value": "5.11067008972", "last_time": "1539976550000"}, "Path": "/Dominos-58/Meter4/CurrentRPhase", "Readings": [[1540208575000.0, 5.1431660652160645]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "CurrentRPhase", "B_PHASE_MULTIPLIER": "None", "B_PHASE": "Lighting + Signage", "VARIABLE_B_PHASE": "None", "R_PHASE_MULTIPLIER": "None", "VARIABLE_Y_PHASE": "None", "R_PHASE": "Makeline", "Y_PHASE": "Exhaust Y Phase", "MODBUS_ID": "4", "Operator": "null[]", "Y_PHASE_MULTIPLIER": "None", "VARIABLE_R_PHASE": "None"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Spare", "Model": "LGPlus", "MeterID": "4", "DeviceType": "meter", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "3ab63b4a-4c16-54f0-825e-18683f9ccacb", "Custom": {"last_value": "3.08907556534", "last_time": "1539976550000"}, "Path": "/Dominos-58/Meter4/CurrentBPhase", "Readings": [[1540208575000.0, 0.0]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "CurrentBPhase", "B_PHASE_MULTIPLIER": "None", "B_PHASE": "Lighting + Signage", "VARIABLE_B_PHASE": "None", "R_PHASE_MULTIPLIER": "None", "VARIABLE_Y_PHASE": "None", "R_PHASE": "Makeline", "Y_PHASE": "Exhaust Y Phase", "MODBUS_ID": "4", "Operator": "null[]", "Y_PHASE_MULTIPLIER": "None", "VARIABLE_R_PHASE": "None"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Spare", "Model": "LGPlus", "MeterID": "4", "DeviceType": "meter", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}]\r\n'

# %%
type(data)
# Out:
# str

# %%
for line in data.split('\n'):
    print(line)
    print()
# Out:
# [{"uuid": "db7b0dff-1762-55b0-80bb-17c372663691", "Custom": {"last_value": "2.5", "last_time": "1539976567000"}, "Path": "/Dominos-58/TemperatureSensor102/Temperature", "Readings": [[1540208566000.0, 2.31]], "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "Celsius", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "Temperature", "HARDWARE_VERSION": "13", "ADDRESS": "2C:3A:E8:18:49:20", "Operator": "null[]", "FIRMWARE_VERSION": "4.3.1", "WIFI_SSID": "ZT_MAIN_DOM58"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"LoadType": "Makeline", "Model": "TemperatureLite", "MeterID": "102", "DeviceType": "temperature", "Variable_LoadType": "None"}, "Controller": {"HwID": "DOM058", "ip_address": "10.8.26.11", "Location": "['19.016485', '72.829172']", "SD": "0x5344"}, "ControllerLocation": {"Campus": "Dominos-58-New"}}}, {"uuid": "b432ad91-e1a3-5575-ba3f-c1662353e60e", "Custom": {"last_value": "6.2618355751", "last_time": "1539976551000"}
# ...

# %%
import json

# %%
def parser(data):
    """Parse a response body from the server.  Since this may include
multiple lines, we need to be careful to do this right and merge the
results together."""
    rv = {}
    for line in data.split('\n'):
        if len(line.strip()) == 0:
            continue
        line_obj = json.loads(line)

        if not isinstance(line_obj, list):
            return data
        if len(line_obj) == 0: continue

        for v in line_obj:
            if not 'uuid' in v:
                return line_obj
            # raise SmapException("Invalid sMAP object: " + str(v))
            id = v['uuid']
            if not id in rv:
                rv[id] = v
            else:
                if 'Readings' in v and 'Readings' in rv[id]:
                    rv[id]['Readings'].extend(v['Readings'])
                    del v['Readings']
                rv[id] = dict_merge(rv[id], v)
    return list(rv.values())

# %%
parser(data)
# Out:
# [{u'Custom': {u'last_time': u'1539976550000', u'last_value': u'5.11067008972'},
#   u'Metadata': {u'Controller': {u'HwID': u'DOM058',
#     u'Location': u"['19.016485', '72.829172']",
#     u'SD': u'0x5344',
#     u'ip_address': u'10.8.26.11'},
#    u'ControllerLocation': {u'Campus': u'Dominos-58-New'},
#    u'Controller_ID': u'/Dominos-58',
#    u'Extra': {u'B_PHASE': u'Lighting + Signage',
#     u'B_PHASE_MULTIPLIER': u'None',
#     u'MODBUS_ID': u'4',
#     u'Operator': u'null[]',
#     u'PhysicalParameter': u'CurrentRPhase',
#     u'R_PHASE': u'Makeline',
#     u'R_PHASE_MULTIPLIER': u'None',
#     u'VARIABLE_B_PHASE': u'None',
#     u'VARIABLE_R_PHASE': u'None',
#     u'VARIABLE_Y_PHASE': u'None',
#     u'Y_PHASE': u'Exhaust Y Phase',
#     u'Y_PHASE_MULTIPLIER': u'None'},
#    u'Instrument': {u'DeviceType': u'meter',
#     u'LoadType': u'Spare',
#     u'MeterID': u'4',
#     u'Model': u'LGPlus',
#     u'Variable_LoadType': u'None'},
#    u'SourceName': u'Dominos'},
# ...

# %%
json.dumps(parser(data))
# Out:
# '[{"uuid": "27fd04f8-82a1-57b8-bf1a-da5b91174d97", "Readings": [[1540208575000.0, 5.1431660652160645]], "Path": "/Dominos-58/Meter4/CurrentRPhase", "Custom": {"last_value": "5.11067008972", "last_time": "1539976550000"}, "Properties": {"Timezone": "Asia/Kolkata", "UnitofMeasure": "", "ReadingType": "double"}, "Metadata": {"Extra": {"PhysicalParameter": "CurrentRPhase", "B_PHASE_MULTIPLIER": "None", "B_PHASE": "Lighting + Signage", "VARIABLE_B_PHASE": "None", "R_PHASE_MULTIPLIER": "None", "VARIABLE_Y_PHASE": "None", "R_PHASE": "Makeline", "Y_PHASE": "Exhaust Y Phase", "MODBUS_ID": "4", "Operator": "null[]", "Y_PHASE_MULTIPLIER": "None", "VARIABLE_R_PHASE": "None"}, "SourceName": "Dominos", "Controller_ID": "/Dominos-58", "Instrument": {"DeviceType": "meter", "Model": "LGPlus", "MeterID": "4", "LoadType": "Spare", "Variable_LoadType": "None"}, "Controller": {"ip_address": "10.8.26.11", "HwID": "DOM058", "Location": "[\'19.016485\', \'72.829172\']", "SD": "0x5344"}, "ControllerLocation"
# ...
